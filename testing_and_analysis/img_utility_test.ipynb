# %%
import img_utility

# %%
path = r'data\data_fb\img\01235.png'

# %%
img_list = img_utility.load_img(path)

# %%
img_utility.show_img(img_list, size=(10,5))

# %%
img_utility.get_edge_colors(img_list)
# Out:
# 39.398542805100185
